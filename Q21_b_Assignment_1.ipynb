# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm

# %%
Assignment_1_Q21_b= pd.read_csv('wc-at.csv')
Assignment_1_Q21_b
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# 5     71.85   21.68
# 6     80.90   29.08
# 7     83.40   32.98
# 8     63.50   11.44
# 9     73.20   32.22
# 10    71.90   28.32
# 11    75.00   43.86
# 12    73.10   38.21
# 13    79.00   42.48
# 14    77.00   30.96
# 15    68.85   55.78
# 16    75.95   43.78
# 17    74.15   33.41
# 18    73.80   43.35
# 19    75.90   29.31
# 20    76.85   36.60
# 21    80.90   40.25
# 22    79.90   35.43
# 23    89.20   60.09
# 24    82.00   45.84
# 25    92.00   70.40
# 26    86.60   83.45
# 27    80.50   84.30
# 28    86.00   78.89
# 29    82.50   64.75
# ..      ...     ...
# 79   109.00  192.00
# 80   103.50  132.00
# 81   110.00  126.00
# 82   110.00  153.00
# 83   112.00  158.00
# 84   108.50  183.00
# 85   104.00  184.00
# 86   111.00  121.00
# 87   108.50  159.00
# 88   121.00  245.00
# 89   109.00  137.00
# 90    97.50  165.00
# 91   105.50  152.00
# ...

# %%
sns.boxplot(Assignment_1_Q21_b.Waist)

# %%
sns.distplot(Assignment_1_Q21_b.AT,label='Assignment_1_Q21_b ~ AT')
plt.xlabel('AT')
plt.ylabel('Density')
plt.show()

# %%
sns.distplot(Assignment_1_Q21_b.Waist,label='Assignment_1_Q21_b ~ Waist')
plt.xlabel('Waist')
plt.ylabel('Density')
plt.show()
